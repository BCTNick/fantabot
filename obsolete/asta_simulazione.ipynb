# %% [markdown]
# # Libraries

# %%
import random
import pandas as pd
from typing import Dict, List, Optional
from dataclasses import dataclass
import logging
from datetime import datetime

# %% [markdown]
# ## Players

# %%
@dataclass
class Player:
    # Initial data (from excel file)
    name: str
    team: str
    role: str  # 'GK', 'DEF', 'MID', 'ATT'
    evaluation: int

    ## Calculated after the importing of the file
    standardized_evaluation: float = 0.0  # Between 0 and 1
    ranking: int = 0  # Rank based on evaluation
    
    # Final results (after auction)
    fantasy_team: Optional[str] = None  # Which agent bought the player
    final_cost: int = None  # Final price paid

def calculate_standardized_and_ranking(players: List[Player]) -> List[Player]:
    """Calculate standardized evaluation and ranking for all players"""
    # Sort players by evaluation (highest first)
    sorted_players = sorted(players, key=lambda p: p.evaluation, reverse=True)
    
    # Get min and max evaluations for standardization
    max_eval = max(p.evaluation for p in players)
    min_eval = min(p.evaluation for p in players)
    eval_range = max_eval - min_eval
    
    # Assign rankings and standardized evaluations
    for i, player in enumerate(sorted_players):
        player.ranking = i + 1  # Ranking starts from 1
        # Standardize: (value - min) / (max - min)
        if eval_range > 0:
            player.standardized_evaluation = (player.evaluation - min_eval) / eval_range
        else:
            player.standardized_evaluation = 0.5  # If all players have same evaluation
    
    return players

## Import players from list
# Read Excel file
df = pd.read_excel("data/players_list.xlsx")

# Create Player objects
players = []
for _, row in df.iterrows():
    player = Player(
        name=row['name'],
        team=row['team'], 
        role=row['role'],
        evaluation=row['evaluation']
    )
    players.append(player)

# Calculate standardized evaluation and ranking
players = calculate_standardized_and_ranking(players)

print(players)
# Out:
# [Player(name='Sommer', team='Inter', role='GK', evaluation=90, standardized_evaluation=0.23482849604221637, ranking=38, fantasy_team=None, final_cost=None), Player(name='Di Gregorio', team='Juventus', role='GK', evaluation=83, standardized_evaluation=0.21635883905013192, ranking=41, fantasy_team=None, final_cost=None), Player(name='Maignan', team='Milan', role='GK', evaluation=81, standardized_evaluation=0.21108179419525067, ranking=43, fantasy_team=None, final_cost=None), Player(name='Meret', team='Napoli', role='GK', evaluation=92, standardized_evaluation=0.24010554089709762, ranking=36, fantasy_team=None, final_cost=None), Player(name='Svilar', team='Roma', role='GK', evaluation=82, standardized_evaluation=0.21372031662269128, ranking=42, fantasy_team=None, final_cost=None), Player(name='Carnesecchi', team='Atalanta', role='GK', evaluation=71, standardized_evaluation=0.18469656992084432, ranking=48, fantasy_team=None, final_cost=None), Player(name='De Gea', team='Fiorentina', role='GK', evaluation=62, standardized_evaluation=0.16094986807387862, ranking=53, fantasy_team=None, final_cost=None), Player(name='Provedel', team='Lazio', role='GK', evaluation=54, standardized_evaluation=0.13984168865435356, ranking=62, fantasy_team=None, final_cost=None), Player(name='Skorupski', team='Bologna', role='GK', evaluation=49, standardized_evaluation=0.1266490765171504, ranking=70, fantasy_team=None, final_cost=None), Player(name='Butez', team='Como', role='GK', evaluation=32, standardized_evaluation=0.08179419525065963, ranking=100, fantasy_team=None, final_cost=None), Player(name='Israel', team='Torino', role='GK', evaluation=30, standardized_evaluation=0.07651715039577836, ranking=107, fantasy_team=None, final_cost=None), Player(name='Leali', team='Genoa', role='GK', evaluation=28, standardized_evaluation=0.0712401055408971, ranking=114, fantasy_team=None, final_cost=None), Player(name='Caprile', team='Cagliari', role='GK', evaluation=18, standardized_evaluation=0.044854881266490766, ranking=188, fantasy_team=None, final_cost=None), Player(name='Suzuki', team='Parma', role='GK', evaluation=15, standardized_evaluation=0.036939313984168866, ranking=221, fantasy_team=None, final_cost=None), Player(name='Turati', team='Sassuolo', role='GK', evaluation=13, standardized_evaluation=0.0316622691292876, ranking=244, fantasy_team=None, final_cost=None), Player(name='Falcone', team='Lecce', role='GK', evaluation=14, standardized_evaluation=0.03430079155672823, ranking=230, fantasy_team=None, final_cost=None), Player(name='Okoye', team='Udinese', role='GK', evaluation=17, standardized_evaluation=0.04221635883905013, ranking=200, fantasy_team=None, final_cost=None), Player(name='Audero', team='Cremonese', role='GK', evaluation=12, standardized_evaluation=0.029023746701846966, ranking=258, fantasy_team=None, final_cost=None), Player(name='Montipò', team='Verona', role='GK', evaluation=10, standardized_evaluation=0.023746701846965697, ranking=292, fantasy_team=None, final_cost=None), Player(name='Milinkovic-Savic V.', team='Napoli', role='GK', evaluation=11, standardized_evaluation=0.026385224274406333, ranking=272, fantasy_team=None, final_cost=None), Player(name='Sava', team='Udinese', role='GK', evaluation=8, standardized_evaluation=0.018469656992084433, ranking=335, fantasy_team=None, final_cost=None), Player(name='Ravaglia F.', team='Bologna', role='GK', evaluation=9, standardized_evaluation=0.021108179419525065, ranking=310, fantasy_team=None, final_cost=None), Player(name='Mandas', team='Lazio', role='GK', evaluation=12, standardized_evaluation=0.029023746701846966, ranking=259, fantasy_team=None, final_cost=None), Player(name='Scuffet', team='Pisa', role='GK', evaluation=5, standardized_evaluation=0.010554089709762533, ranking=389, fantasy_team=None, final_cost=None), Player(name='Semper', team='Pisa', role='GK', evaluation=7, standardized_evaluation=0.0158311345646438, ranking=361, fantasy_team=None, final_cost=None), Player(name='Martinez ...

# %% [markdown]
# ## Rules

# %%
class Slots:
    def __init__(self, gk: int = 3, def_: int = 8, mid: int = 8, att: int = 6):
        self.gk = gk
        self.def_ = def_
        self.mid = mid
        self.att = att
        
    def to_dict(self) -> Dict[str, int]:
        return {'GK': self.gk, 'DEF': self.def_, 'MID': self.mid, 'ATT': self.att}

# %% [markdown]
# ## Agents

# %%
class Squad:
    def __init__(self, players: List['Player']):
        self._players = players

    def __iter__(self):
        return iter(self._players)

    def __len__(self):
        return len(self._players)

    def __getitem__(self, idx):
        return self._players[idx]

    @property
    def gk(self):
        return [p for p in self._players if p.role == "GK"]

    @property
    def def_(self):
        return [p for p in self._players if p.role == "DEF"]

    @property
    def mid(self):
        return [p for p in self._players if p.role == "MID"]

    @property
    def att(self):
        return [p for p in self._players if p.role == "ATT"]
    
    def objective(self, bestxi: bool = False, standardized: bool = False) -> float:
        """
        Calculate objective function for this squad
        
        Args:
            bestxi: If True, calculate only best starting XI (1 GK + 4 DEF + 4 MID + 3 ATT)
                   If False, calculate total squad evaluation
            standardized: If True, use standardized_evaluation
                         If False, use regular evaluation
        
        Returns:
            float: The calculated objective value
        """
        eval_attr = 'standardized_evaluation' if standardized else 'evaluation'
        
        if bestxi:
            # Best starting XI: 1 GK + 4 DEF + 4 MID + 3 ATT
            best_gk = max(self.gk, key=lambda p: getattr(p, eval_attr), default=None)
            best_def = sorted(self.def_, key=lambda p: getattr(p, eval_attr), reverse=True)[:4]
            best_mid = sorted(self.mid, key=lambda p: getattr(p, eval_attr), reverse=True)[:4]
            best_att = sorted(self.att, key=lambda p: getattr(p, eval_attr), reverse=True)[:3]
            
            total = 0
            if best_gk:
                total += getattr(best_gk, eval_attr)
            total += sum(getattr(p, eval_attr) for p in best_def + best_mid + best_att)
            
            return total
        else:
            # Total squad evaluation
            return sum(getattr(p, eval_attr) for p in self._players)

class Agent:
    def __init__(self, agent_id: str):
        self.agent_id = agent_id
        self.current_credits = 1000  # Default, will be set properly in initialize
        self._squad: List[Player] = []

    @property
    def squad(self):
        return Squad(self._squad)
    
    def initialize(self, listone: List[Player], slots: Slots, initial_credits: int, num_participants: int):
        """Initialize agent with auction environment - to be overridden by subclasses if needed"""
        self.current_credits = initial_credits

    def make_offer_decision(self, current_player, current_price, highest_bidder, player_list) -> str:
        raise NotImplementedError("This method should be implemented by subclasses.")

class RandomAgent(Agent):
    def make_offer_decision(self, current_player, current_price, highest_bidder, player_list) -> str:
        return "offer_+1" if random.random() < 0.5 else "no_offer"

class CapAgent(Agent):
    def __init__(self, agent_id: str, cap_strategy: str = "value_based", bestxi_budget: float = 0.9):
        super().__init__(agent_id)
        self.cap_strategy = cap_strategy
        self.bestxi_budget = bestxi_budget
        self.listone = {}  # Will be filled during initialize
        self.players_caps = {}  # Dictionary to store player caps
    
    def initialize(self, listone: List[Player], slots: Slots, initial_credits: int, num_participants: int):
        """Initialize agent with auction environment"""
        super().initialize(listone, slots, initial_credits, num_participants)

        if self.cap_strategy == "value_based":

            # Calculate average budget per team for the best players 
            avg_budget_per_team = initial_credits * self.bestxi_budget

            # Filter best players by role based on actual slot requirements:
            best_gk = sorted([p for p in listone if p.role == "GK"], 
                           key=lambda p: p.evaluation, reverse=True)[:1 * num_participants]
            best_def = sorted([p for p in listone if p.role == "DEF"], 
                            key=lambda p: p.evaluation, reverse=True)[:3 * num_participants]
            best_mid = sorted([p for p in listone if p.role == "MID"], 
                            key=lambda p: p.evaluation, reverse=True)[:3 * num_participants]
            best_att = sorted([p for p in listone if p.role == "ATT"], 
                            key=lambda p: p.evaluation, reverse=True)[:3 * num_participants]
            
            # Combine all best players
            best_players = best_gk + best_def + best_mid + best_att

            # Calculate total evaluation points available
            total_evaluation = sum(p.evaluation for p in best_players)

            # Calculate value per evaluation point
            value_per_point = (num_participants * avg_budget_per_team) / total_evaluation

            # For ONLY the best players, compute cap and store in dictionary
            for player in best_players:
                cap = player.evaluation * value_per_point
                self.players_caps[player.name] = cap


            # Calculate average budget per team for the acceptable players (10% of total credits)
            avg_budget_per_team = initial_credits * (1 - self.bestxi_budget)

            # Filter acceptable players by role based on actual slot requirements:
            acceptable_gk = sorted([p for p in listone if p.role == "GK"], 
                           key=lambda p: p.evaluation, reverse=True)[:slots.gk * num_participants]
            acceptable_def = sorted([p for p in listone if p.role == "DEF"], 
                            key=lambda p: p.evaluation, reverse=True)[:slots.def_ * num_participants]
            acceptable_mid = sorted([p for p in listone if p.role == "MID"], 
                            key=lambda p: p.evaluation, reverse=True)[:slots.mid * num_participants]
            acceptable_att = sorted([p for p in listone if p.role == "ATT"], 
                            key=lambda p: p.evaluation, reverse=True)[:slots.att * num_participants]
            
            # Combine all accptable players and remove the best
            acceptable_players = acceptable_gk + acceptable_def + acceptable_mid + acceptable_att 
            acceptable_players = [p for p in acceptable_players if p not in best_players] 

            # Calculate total evaluation points available
            total_evaluation = sum(p.evaluation for p in acceptable_players)

            # Calculate value per evaluation point
            value_per_point = (num_participants * avg_budget_per_team) / total_evaluation

            # For ONLY the average players, compute cap and store in dictionary
            for player in acceptable_players:
                cap = player.evaluation * value_per_point
                self.players_caps[player.name] = cap
    
    def make_offer_decision(self, current_player, current_price, highest_bidder, player_list) -> str:
        """Make bidding decision based on cap calculation"""

        if current_player.name not in self.players_caps:
            return "offer_+1" if random.random() < 0.01 else "no_offer"
        
        max_bid = self.players_caps[current_player.name]
    
        # Don't bid if current price exceeds our calculated maximum
        if current_price >= max_bid:
            return "no_offer"
        else:
            return "offer_+1"

# %% [markdown]
# ## Auction Class

# %%
class Auction:
    def __init__(self, slots: Slots, agents: List[Agent], players: List[Player] = players, initial_credits: int = 1000,):
        ## Rules
        self.slots = slots.to_dict()
        self.initial_credits = initial_credits

        ## Rest
        self.agents = agents
        self.players = players

        # Initialize ALL agents with auction variables
        for agent in self.agents:
            agent.initialize(players, slots, initial_credits, len(agents))
                
    def can_participate_in_bid(self, agent: Agent, current_price: int, position: str, slots: Dict[str, int]) -> bool:
        """
        Check if the agent is not the highest bidder, has a free slot for the given position
        and can afford to buy the player while still keeping enough credits
        to fill the rest of their squad.
        """
        
        # Check if they have at least one free slot in this position
        role_map = {"GK": agent.squad.gk, "DEF": agent.squad.def_, "MID": agent.squad.mid, "ATT": agent.squad.att}
        if len(role_map[position]) >= slots[position]:
            return False
        
        # Calculate credits left after the purchase (current_price + 1 is what they would pay)
        credits_after_purchase = agent.current_credits - (current_price + 1)

        # Calculate total max slots in the squad (all positions)
        total_slots = sum(slots.values())

        # Calculate total players currently in the squad (all positions)
        total_players = len(agent.squad)

        # Since we are bidding for a player in 'position', this bid would fill one slot
        remaining_slots = total_slots - (total_players + 1)

        # They can participate only if remaining credits cover minimum needed
        return credits_after_purchase >= remaining_slots
        
    def single_player(self, player: Player): 
        """Auction for a single player"""
        
        # Set initial state
        self.current_player = player
        self.current_price = 0  # Start at 0
        self.highest_bidder = None
        
        agent_index = 0  # Track which agent's turn it is
        no_bid_count = 0  # Count consecutive agents who didn't bid
        
        # Log auction start
        logger = logging.getLogger()
        logger.info(f"\n🏆 AUCTION START: {player.name} ({player.role}) - Evaluation: {player.evaluation}")
        
        while True:
            current_agent = self.agents[agent_index]
            
            # Check if agent can participate
            if (self.can_participate_in_bid(agent= current_agent, current_price = self.current_price, position = player.role, slots= self.slots)):
                
                # Agent makes decision
                decision = current_agent.make_offer_decision(
                    current_player=player,
                    current_price=self.current_price,
                    highest_bidder=self.highest_bidder,
                    player_list=self.players
                )
                
                if decision == "offer_+1":
                    self.current_price += 1
                    self.highest_bidder = current_agent.agent_id
                    no_bid_count = 0  # Reset counter
                    
                    # Log the bid
                    logger.info(f"  💰 {current_agent.agent_id} bids {self.current_price} (credits left: {current_agent.current_credits})")
                else:
                    no_bid_count += 1
                    
                    # Log the pass
                    logger.info(f"  ❌ {current_agent.agent_id} passes at {self.current_price}")
            else:
                no_bid_count += 1
                
                # Log why agent can't participate
                logger.info(f"  🚫 {current_agent.agent_id} cannot bid (no slot/credits)")
            
            # Move to next agent
            agent_index = (agent_index + 1) % len(self.agents)
            
            # Check if full round completed with no bids
            if no_bid_count >= (len(self.agents)-1):  # -1 because highest bidder is excluded
                break
        
        # Finalize sale
        if self.highest_bidder: #if the highest bid exists
            
            player.fantasy_team = self.highest_bidder
            player.final_cost = self.current_price
            
            # Add player to agent's squad and deduct credits 
            winner_agent = next(agent for agent in self.agents if agent.agent_id == self.highest_bidder)
            winner_agent._squad.append(player)
            winner_agent.current_credits -= self.current_price
            
            logger.info(f"✅ {player.name} SOLD to {self.highest_bidder} for {self.current_price}. Credits remaining: {winner_agent.current_credits}")
            return self.highest_bidder
        else:
            player.fantasy_team = "UNSOLD"  # Mark as unsold instead of None
            player.final_cost = 0
            logger.info(f"❌ {player.name} UNSOLD")
            return None
        
    def run_all(self, auction_type: str = "random", per_ruolo: bool = True):
        """Run auction for all players, role by role if per_ruolo is True.
        Only auction players not already assigned to a fantasy team.
        Returns the updated list of players.
        """
        import logging
        logger = logging.getLogger()
        
        roles = ["GK", "DEF", "MID", "ATT"]
        self.auction_type = auction_type
        self.per_ruolo = per_ruolo

        players_to_auction = self.players[:]
        if auction_type == "random":
            random.shuffle(players_to_auction)
        elif auction_type == "listone":
            players_to_auction.sort(key=lambda p: p.name)
        elif auction_type == "chiamata":
            players_to_auction.sort(key=lambda p: p.evaluation, reverse=True)

        if per_ruolo:
            for role in roles:
                logger.info(f"\n{'='*50}\n🏈 STARTING {role} AUCTIONS\n{'='*50}")
                    
                while True:
                    # Check if all agents have filled their slots for this role
                    all_full = all(len(getattr(agent.squad, role.lower() if role != "DEF" else "def_")) >= self.slots[role] for agent in self.agents)
                    if all_full:
                        break
                    # Find next available player for this role (exclude unsold players)
                    next_player = next((p for p in players_to_auction if p.role == role and p.fantasy_team is None), None)
                    if next_player is None:
                        break  # No more available players for this role
                    self.single_player(next_player)
        else:
            total_slots = sum(self.slots.values())
            while True:
                # Check if all agents have full squads
                all_full = all(len(agent.squad) >= total_slots for agent in self.agents)
                if all_full:
                    break
                # Find next available player (exclude unsold players)
                next_player = next((p for p in players_to_auction if p.fantasy_team is None), None)
                if next_player is None:
                    break  # No more available players
                self.single_player(next_player)

        return None

# %% [markdown]
# ## single player trial

# %%
# Create auction with 4 agents
slots = Slots()
initial_credits = 1000
agents = [
    CapAgent(agent_id="cucco"),
    CapAgent(agent_id="andrea"),
    RandomAgent(agent_id="gianmarco"),
    RandomAgent(agent_id="carlomario")
]  

auction = Auction(slots, agents, players)
haaland = next(p for p in players if p.name == "Sommer")
auction.single_player(haaland)
print(agents[1].players_caps)
# Out:
# 🏆 AUCTION START: Sommer (GK) - Evaluation: 90
#   💰 cucco bids 1 (credits left: 1000)
#   💰 andrea bids 2 (credits left: 1000)
#   ❌ gianmarco passes at 2
#   ❌ carlomario passes at 2
#   💰 cucco bids 3 (credits left: 1000)
#   💰 andrea bids 4 (credits left: 1000)
#   💰 gianmarco bids 5 (credits left: 1000)
#   💰 carlomario bids 6 (credits left: 1000)
#   💰 cucco bids 7 (credits left: 1000)
#   💰 andrea bids 8 (credits left: 1000)
#   💰 gianmarco bids 9 (credits left: 1000)
#   ❌ carlomario passes at 9
#   💰 cucco bids 10 (credits left: 1000)
#   💰 andrea bids 11 (credits left: 1000)
#   💰 gianmarco bids 12 (credits left: 1000)
#   💰 carlomario bids 13 (credits left: 1000)
#   💰 cucco bids 14 (credits left: 1000)
#   💰 andrea bids 15 (credits left: 1000)
#   💰 gianmarco bids 16 (credits left: 1000)
#   💰 carlomario bids 17 (credits left: 1000)
#   💰 cucco bids 18 (credits left: 1000)
#   💰 andrea bids 19 (credits left: 1000)
#   ❌ gianmarco passes at 19
#   💰 carlomario bids 20 (credits left: 1000)
#   💰 cucco bids 21 (credits left: 1000)
#   💰 andrea bids 22 (credits left: 1000)
#   💰 gianmarco bids 23 (credits left: 1000)
#   ❌ carlomario passes at 23
#   💰 cucco bids 24 (credits left: 1000)
#   💰 andrea bids 25 (credits left: 1000)
#   💰 gianmarco bids 26 (credits left: 1000)
#   💰 carlomario bids 27 (credits left: 1000)
#   💰 cucco bids 28 (credits left: 1000)
#   💰 andrea bids 29 (credits left: 1000)
#   💰 gianmarco bids 30 (credits left: 1000)
#   💰 carlomario bids 31 (credits left: 1000)
#   💰 cucco bids 32 (credits left: 1000)
#   💰 andrea bids 33 (credits left: 1000)
#   💰 gianmarco bids 34 (credits left: 1000)
#   💰 carlomario bids 35 (credits left: 1000)
#   💰 cucco bids 36 (credits left: 1000)
#   💰 andrea bids 37 (credits left: 1000)
#   💰 gianmarco bids 38 (credits left: 1000)
#   ❌ carlomario passes at 38
#   💰 cucco bids 39 (credits left: 1000)
#   💰 andrea bids 40 (credits left: 1000)
#   ❌ gianmarco passes at 40
#   ❌ carlomario passes at 40
#   💰 cucco bids 41 (credits left: 1000)
#   💰 andrea bids 42 (credits left: 1000)
#   💰 gianmarco bids 43 (credits left: 1000)
#   ❌ carlomario passes at 43
#   💰 cucco bids 44 (credits left: 1000)
#   💰 andrea bids 45 (credits left: 1000)
#   💰 gianmarco bids 46 (credits left: 1000)
#   ❌ carlomario passes at 46
#   💰 cucco bids 47 (credits left: 1000)
#   💰 andrea bids 48 (credits left: 1000)
#   ❌ gianmarco passes at 48
#   ❌ carlomario passes at 48
#   💰 cucco bids 49 (credits left: 1000)
#   💰 andrea bids 50 (credits left: 1000)
#   💰 gianmarco bids 51 (credits left: 1000)
#   ❌ carlomario passes at 51
#   💰 cucco bids 52 (credits left: 1000)
#   💰 andrea bids 53 (credits left: 1000)
#   ❌ gianmarco passes at 53
#   ❌ carlomario passes at 53
#   ❌ cucco passes at 53
# ✅ Sommer SOLD to andrea for 53. Credits remaining: 947
# {'Meret': 53.41074020319303, 'Sommer': 52.24963715529753, 'Di Gregorio': 48.185776487663276, 'Svilar': 47.60522496371553, 'Dumfries': 58.055152394775035, 'Dimarco': 55.73294629898403, 'Gosens': 49.92743105950653, 'Bastoni': 45.283018867924525, 'Zortea': 39.477503628447025, 'Cambiaso': 36.574746008708274, 'Angelino': 34.25253991291727, 'Di Lorenzo': 33.09143686502177, 'Zappacosta': 30.769230769230766, 'Wesley': 30.18867924528302, 'Bellanova': 30.18867924528302, 'Tavares N.': 28.447024673439767, 'Orsolini': 127.72133526850507, 'Pulisic': 125.39912917271407, 'Zaccagni': 117.85195936139331, 'McTominay': 116.69085631349782, 'Gudmundsson A.': 102.75761973875181, 'Calhanoglu': 88.24383164005805, 'De Bruyne': 85.3410740203193, 'Paz N.': 69.08563134978229, 'Conceicao': 52.83018867924528, 'Odgaard': 45.283018867924525, 'Thuram K.': 37.73584905660377, 'Ederson D.S.': 33.67198838896952, 'Martinez L.': 220.60957910014514, 'Kean': 217.70682148040638, 'Lukaku': 197.96806966618286, 'Thuram': 184.6153846153846, 'Lookman': 171.8432510885341, 'David': 161.39332365747458, 'Gimenez': 151.52394775036285, 'Dybala': 146.2989840348331, 'Leao': 140.49346879535557, 'Yildiz': 136.42960812772134, 'De Ketelaere': 98.69375907111755, 'Dovbyk': 96.37155297532655, 'Maignan': 9.52941176470588, 'Carnesecchi': 8.352941176470587, 'De Gea': 7.294117647058822, 'Provedel': 6.352941176470587, 'Skorupski': 5.764705882352939, 'Butez': 3.7647058823529402, 'Israel': 3.5294117647058814, 'Leali': 3.2941176470588225, 'Bremer': 5.176470588235293, 'Buongiorno': 5.176470588235293, 'Dodò': 5.176470588235293, 'Hien': 4.705882352941176, 'Estupinan': 4.352941176470587, 'Solet': 4.352941176470587, 'Rrahmani': 3.7647058823529402, 'Martin': 3.7647058823529402, 'Carlos Augusto': 3.647058823529411, 'Mancini': 3.5294117647058814, 'Valeri': 3.1764705882352935, 'Olivera': 3.058823529411764, "N'Dicka": 3.058823529411764, 'Acerbi': 3.058823529411764, 'Beukema': 2.9411764705882346, 'Tomori': 2.9411764705882346, 'Miranda J.': 2.823529411764705, 'Bisseck': 2.823529411764705, 'Kalulu': 2.823529411764705, 'Scalvini': 2.823529411764705, 'Barella': 6.823529411764704, 'Politano': 6.470588235294116, 'Zambo Anguissa': 6.352941176470587, 'Frattesi': 6.352941176470587, 'Vlasic': 5.4117647058823515, 'Isaksen': 5.2941176470588225, 'Neres': 5.058823529411764, 'Tramoni M.': 4.941176470588234, 'Konè M.': 4.823529411764705, 'Koopmeiners': 4.705882352941176, 'Modric': 4.705882352941176, 'Saelemaekers': 4.470588235294117, 'Fofana Y.': 4.352941176470587, 'Vandeputte': 4.235294117647058, 'Fazzini': 4.235294117647058, 'Samardzic': 4.117647058823528, 'Bernabè': 4.117647058823528, 'De Roon': 3.999999999999999, 'Gronbaek': 3.999999999999999, 'Mandragora': 3.8823529411764697, 'Castellanos': 18.235294117647054, 'Dia': 17.29411764705882, 'Berardi': 17.05882352941176, 'Castro S.': 16.470588235294112, 'Immobile': 16.470588235294112, 'Krstovic': 16.235294117647054, 'Ferguson E.': 16.117647058823525, 'Soulè': 14.705882352941172, 'Zapata D.': 13.17647058823529, 'Scamacca': 11.999999999999996, 'Vlahovic': 11.64705882352941, 'Diao': 11.176470588235292}

# %% [markdown]
# ## whole auction trial

# %%
if __name__ == "__main__":
    
    # Set up logging - clear existing handlers first
    logger = logging.getLogger()
    for handler in logger.handlers[:]:
        logger.removeHandler(handler)
    
    log_filename = f"auction_log_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"
    logging.basicConfig(
        level=logging.INFO,
        format='%(message)s',
        handlers=[
            logging.FileHandler(log_filename, encoding='utf-8'),
            logging.StreamHandler()  # This still prints to console too
        ],
        force=True  # Force reconfiguration
    )
    logger = logging.getLogger()
    
    # Create the characteristics of the auction
    slots = Slots()
    initial_credits = 1000
    agents = [
        CapAgent(agent_id="cap agent 1", bestxi_budget= 1.2),
        CapAgent(agent_id="cap agent 2",  bestxi_budget= 1),
        CapAgent(agent_id="cap agent 3",  bestxi_budget= 0.9),
        CapAgent(agent_id="cap agent 4",  bestxi_budget= 0.8),
        RandomAgent(agent_id="davide"),
        RandomAgent(agent_id="tommi"),
        RandomAgent(agent_id="gianmarco"),
        RandomAgent(agent_id="carlomario")
    ]  
    auction_type = "random"
    per_ruolo = True
    auction = Auction(slots, agents)

    # Log auction and agent configuration
    logger.info("\n⚙️ AUCTION CONFIGURATION")
    logger.info("-" * 40)
    logger.info(f"📊 Slots per team:")
    logger.info(f"  GK: {slots.gk}")
    logger.info(f"  DEF: {slots.def_}")
    logger.info(f"  MID: {slots.mid}")
    logger.info(f"  ATT: {slots.att}")
    logger.info(f"💰 Initial credits per agent: {initial_credits}")
    logger.info(f"👥 Number of agents: {len(agents)}")
    logger.info(f"📋 Total players available: {len(players)}")
    logger.info(f"  Auction type: {auction_type}")
    logger.info(f"  Per role: {per_ruolo}")    
    logger.info("\n🤖 AGENT CONFIGURATIONS")
    logger.info("-" * 40)
    for agent in agents:
        if isinstance(agent, CapAgent):
            logger.info(f"  {agent.agent_id}: CapAgent (strategy: {agent.cap_strategy})")
        elif isinstance(agent, RandomAgent):
            logger.info(f"  {agent.agent_id}: RandomAgent")
        else:
            logger.info(f"  {agent.agent_id}: {type(agent).__name__}")


    logger.info("🏁 AUCTION SIMULATION STARTED")
    logger.info(f"📅 Timestamp: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    logger.info("="*60)
    logger.info("\n" + "="*60)

    # Run auction
    auction.run_all(auction_type=auction_type, per_ruolo=per_ruolo)
    

    logger.info("🏁 AUCTION COMPLETED!")
    logger.info(f"📅 Timestamp: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    logger.info("="*60)
    
    # Log all team information instead of creating Excel files
    logger.info("\n" + "="*80)
    logger.info("📊 FINAL TEAMS BY AGENT")
    logger.info("="*80)
    
    for agent in auction.agents:
        logger.info(f"\n🏆 TEAM: {agent.agent_id.upper()}")
        logger.info("-" * 50)
        
        # Log squad players
        for player in agent.squad:
            logger.info(f"  {player.role:3} | {player.name:20} | {player.team:15} | Eval: {player.evaluation:3} | Cost: {player.final_cost:3}")
        
        # Calculate squad objectives
        total_eval = agent.squad.objective()
        total_std_eval = agent.squad.objective(standardized=True)
        bestxi_eval = agent.squad.objective(bestxi=True)
        bestxi_std_eval = agent.squad.objective(bestxi=True, standardized=True)
        
        # Log summary metrics
        logger.info("\n📈 SQUAD METRICS:")
        logger.info(f"  Total Squad Evaluation: {total_eval}")
        logger.info(f"  Total Squad Standardized: {total_std_eval:.3f}")
        logger.info(f"  Best XI Evaluation: {bestxi_eval}")
        logger.info(f"  Best XI Standardized: {bestxi_std_eval:.3f}")
        logger.info(f"  Credits Remaining: {agent.current_credits}")
        logger.info(f"  Total Credits Spent: {1000 - agent.current_credits}")
        logger.info("")
        logger.info("="*60)

    
    for agent in auction.agents:
        logger.info(f"\n🏆 TEAM: {agent.agent_id.upper()}")
        logger.info("-" * 50)
                # Calculate squad objectives
        total_eval = agent.squad.objective()
        total_std_eval = agent.squad.objective(standardized=True)
        bestxi_eval = agent.squad.objective(bestxi=True)
        bestxi_std_eval = agent.squad.objective(bestxi=True, standardized=True)
                # Log summary metrics
        logger.info("\n📈 SQUAD METRICS:")
        logger.info(f"  Total Squad Evaluation: {total_eval}")
        logger.info(f"  Total Squad Standardized: {total_std_eval:.3f}")
        logger.info(f"  Best XI Evaluation: {bestxi_eval}")
        logger.info(f"  Best XI Standardized: {bestxi_std_eval:.3f}")
        logger.info(f"  Credits Remaining: {agent.current_credits}")
        logger.info(f"  Total Credits Spent: {1000 - agent.current_credits}")
        logger.info("")

    logger.info(f"\n📁 Complete log saved to: {log_filename}")
# Out:
# ⚙️ AUCTION CONFIGURATION
# ----------------------------------------
# 📊 Slots per team:
#   GK: 3
#   DEF: 8
#   MID: 8
#   ATT: 6
# 💰 Initial credits per agent: 1000
# 👥 Number of agents: 8
# 📋 Total players available: 513
#   Auction type: random
#   Per role: True
#
# 🤖 AGENT CONFIGURATIONS
# ----------------------------------------
#   cap agent 1: CapAgent (strategy: value_based)
#   cap agent 2: CapAgent (strategy: value_based)
#   cap agent 3: CapAgent (strategy: value_based)
#   cap agent 4: CapAgent (strategy: value_based)
#   davide: RandomAgent
#   tommi: RandomAgent
#   gianmarco: RandomAgent
#   carlomario: RandomAgent
# 🏁 AUCTION SIMULATION STARTED
# 📅 Timestamp: 2025-08-02 22:59:08
# ============================================================
#
# ============================================================
#
# ==================================================
# 🏈 STARTING GK AUCTIONS
# ==================================================
#
# 🏆 AUCTION START: Sommariva (GK) - Evaluation: 1
#   ❌ cap agent 1 passes at 0
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   ❌ cap agent 4 passes at 0
#   💰 davide bids 1 (credits left: 1000)
#   💰 tommi bids 2 (credits left: 1000)
#   ❌ gianmarco passes at 2
#   ❌ carlomario passes at 2
#   ❌ cap agent 1 passes at 2
#   ❌ cap agent 2 passes at 2
#   ❌ cap agent 3 passes at 2
#   ❌ cap agent 4 passes at 2
#   ❌ davide passes at 2
# ✅ Sommariva SOLD to tommi for 2. Credits remaining: 998
#
# 🏆 AUCTION START: Nunziante (GK) - Evaluation: 1
#   ❌ cap agent 1 passes at 0
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   ❌ cap agent 4 passes at 0
#   💰 davide bids 1 (credits left: 1000)
#   💰 tommi bids 2 (credits left: 998)
#   ❌ gianmarco passes at 2
#   💰 carlomario bids 3 (credits left: 1000)
#   ❌ cap agent 1 passes at 3
#   ❌ cap agent 2 passes at 3
#   ❌ cap agent 3 passes at 3
#   ❌ cap agent 4 passes at 3
#   💰 davide bids 4 (credits left: 1000)
#   💰 tommi bids 5 (credits left: 998)
#   💰 gianmarco bids 6 (credits left: 1000)
#   ❌ carlomario passes at 6
#   ❌ cap agent 1 passes at 6
#   ❌ cap agent 2 passes at 6
#   ❌ cap agent 3 passes at 6
#   ❌ cap agent 4 passes at 6
#   ❌ davide passes at 6
#   💰 tommi bids 7 (credits left: 998)
#   ❌ gianmarco passes at 7
#   ❌ carlomario passes at 7
#   ❌ cap agent 1 passes at 7
#   ❌ cap agent 2 passes at 7
#   ❌ cap agent 3 passes at 7
#   ❌ cap agent 4 passes at 7
#   💰 davide bids 8 (credits left: 1000)
#   💰 tommi bids 9 (credits left: 998)
#   ❌ gianmarco passes at 9
#   ❌ carlomario passes at 9
#   ❌ cap agent 1 passes at 9
#   ❌ cap agent 2 passes at 9
#   ❌ cap agent 3 passes at 9
#   ❌ cap agent 4 passes at 9
#   💰 davide bids 10 (credits left: 1000)
#   ❌ tommi passes at 10
#   💰 gianmarco bids 11 (credits left: 1000)
#   ❌ carlomario passes at 11
#   ❌ cap agent 1 passes at 11
#   ❌ cap agent 2 passes at 11
#   ❌ cap agent 3 passes at 11
#   ❌ cap agent 4 passes at 11
#   💰 davide bids 12 (credits left: 1000)
#   💰 tommi bids 13 (credits left: 998)
#   💰 gianmarco bids 14 (credits left: 1000)
#   ❌ carlomario passes at 14
#   ❌ cap agent 1 passes at 14
#   ❌ cap agent 2 passes at 14
#   ❌ cap agent 3 passes at 14
#   ❌ cap agent 4 passes at 14
#   ❌ davide passes at 14
#   ❌ tommi passes at 14
# ✅ Nunziante SOLD to gianmarco for 14. Credits remaining: 986
#
# 🏆 AUCTION START: Donnarumma An. (GK) - Evaluation: 1
#   ❌ cap agent 1 passes at 0
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   ❌ cap agent 4 passes at 0
#   💰 davide bids 1 (credits left: 1000)
#   💰 tommi bids 2 (credits left: 998)
#   ❌ gianmarco passes at 2
#   ❌ carlomario passes at 2
#   ❌ cap agent 1 passes at 2
#   ❌ cap agent 2 passes at 2
#   ❌ cap agent 3 passes at 2
#   ❌ cap agent 4 passes at 2
#   💰 davide bids 3 (credits left: 1000)
#   💰 tommi bids 4 (credits left: 998)
#   ❌ gianmarco passes at 4
#   💰 carlomario bids 5 (credits left: 1000)
#   ❌ cap agent 1 passes at 5
#   ❌ cap agent 2 passes at 5
#   ❌ cap agent 3 passes at 5
#   ❌ cap agent 4 passes at 5
#   💰 davide bids 6 (credits left: 1000)
#   💰 tommi bids 7 (credits left: 998)
#   ❌ gianmarco passes at 7
#   💰 carlomario bids 8 (credits left: 1000)
#   ❌ cap agent 1 passes at 8
#   ❌ cap agent 2 passes at 8
#   ❌ cap agent 3 passes at 8
#   ❌ cap agent 4 passes at 8
#   💰 davide bids 9 (credits left: 1000)
#   ❌ tommi passes at 9
#   💰 gianmarco bids 10 (credits left: 986)
#   ❌ carlomario passes at 10
#   ❌ cap agent 1 passes at 10
#   ❌ cap agent 2 passes at 10
#   ❌ cap agent 3 passes at 10
#   ❌ cap agent 4 passes at 10
#   ❌ davide passes at 10
#   ❌ tommi passes at 10
# ✅ Donnarumma An. SOLD to gianmarco for 10. Credits remaining: 976
#
# 🏆 AUCTION START: Di Gennaro (GK) - Evaluation: 1
#   ❌ cap agent 1 passes at 0
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   ❌ cap agent 4 passes at 0
#   💰 davide bids 1 (credits left: 1000)
#   💰 tommi bids 2 (credits left: 998)
#   ❌ gianmarco passes at 2
#   ❌ carlomario passes at 2
#   ❌ cap agent 1 passes at 2
#   ❌ cap agent 2 passes at 2
#   ❌ cap agent 3 passes at 2
#   ❌ cap agent 4 passes at 2
#   ❌ davide passes at 2
# ✅ Di Gennaro SOLD to tommi for 2. Credits remaining: 996
#
# 🏆 AUCTION START: Padelli (GK) - Evaluation: 1
#   ❌ cap agent 1 passes at 0
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   ❌ cap agent 4 passes at 0
#   ❌ davide passes at 0
#   ❌ tommi passes at 0
#   ❌ gianmarco passes at 0
# ❌ Padelli UNSOLD
#
# 🏆 AUCTION START: Christensen O. (GK) - Evaluation: 1
#   ❌ cap agent 1 passes at 0
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   ❌ cap agent 4 passes at 0
#   💰 davide bids 1 (credits left: 1000)
#   💰 tommi bids 2 (credits left: 996)
#   💰 gianmarco bids 3 (credits left: 976)
#   ❌ carlomario passes at 3
#   ❌ cap agent 1 passes at 3
#   ❌ cap agent 2 passes at 3
#   ❌ cap agent 3 passes at 3
#   ❌ cap agent 4 passes at 3
#   💰 davide bids 4 (credits left: 1000)
#   💰 tommi bids 5 (credits left: 996)
#   ❌ gianmarco passes at 5
#   ❌ carlomario passes at 5
#   ❌ cap agent 1 passes at 5
#   ❌ cap agent 2 passes at 5
#   ❌ cap agent 3 passes at 5
#   ❌ cap agent 4 passes at 5
#   ❌ davide passes at 5
# ✅ Christensen O. SOLD to tommi for 5. Credits remaining: 991
#
# 🏆 AUCTION START: Di Gregorio (GK) - Evaluation: 83
#   💰 cap agent 1 bids 1 (credits left: 1000)
#   💰 cap agent 2 bids 2 (credits left: 1000)
#   💰 cap agent 3 bids 3 (credits left: 1000)
#   💰 cap agent 4 bids 4 (credits left: 1000)
#   ❌ davide passes at 4
#   🚫 tommi cannot bid (no slot/credits)
#   ❌ gianmarco passes at 4
#   ❌ carlomario passes at 4
#   💰 cap agent 1 bids 5 (credits left: 1000)
#   💰 cap agent 2 bids 6 (credits left: 1000)
#   💰 cap agent 3 bids 7 (credits left: 1000)
#   💰 cap agent 4 bids 8 (credits left: 1000)
#   💰 davide bids 9 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   💰 gianmarco bids 10 (credits left: 976)
#   ❌ carlomario passes at 10
#   💰 cap agent 1 bids 11 (credits left: 1000)
#   💰 cap agent 2 bids 12 (credits left: 1000)
#   💰 cap agent 3 bids 13 (credits left: 1000)
#   💰 cap agent 4 bids 14 (credits left: 1000)
#   💰 davide bids 15 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   💰 gianmarco bids 16 (credits left: 976)
#   💰 carlomario bids 17 (credits left: 1000)
#   💰 cap agent 1 bids 18 (credits left: 1000)
#   💰 cap agent 2 bids 19 (credits left: 1000)
#   💰 cap agent 3 bids 20 (credits left: 1000)
#   💰 cap agent 4 bids 21 (credits left: 1000)
#   💰 davide bids 22 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   ❌ gianmarco passes at 22
#   ❌ carlomario passes at 22
#   💰 cap agent 1 bids 23 (credits left: 1000)
#   💰 cap agent 2 bids 24 (credits left: 1000)
#   💰 cap agent 3 bids 25 (credits left: 1000)
#   💰 cap agent 4 bids 26 (credits left: 1000)
#   💰 davide bids 27 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   💰 gianmarco bids 28 (credits left: 976)
#   ❌ carlomario passes at 28
#   💰 cap agent 1 bids 29 (credits left: 1000)
#   💰 cap agent 2 bids 30 (credits left: 1000)
#   💰 cap agent 3 bids 31 (credits left: 1000)
#   💰 cap agent 4 bids 32 (credits left: 1000)
#   💰 davide bids 33 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   ❌ gianmarco passes at 33
#   ❌ carlomario passes at 33
#   💰 cap agent 1 bids 34 (credits left: 1000)
#   💰 cap agent 2 bids 35 (credits left: 1000)
#   💰 cap agent 3 bids 36 (credits left: 1000)
#   💰 cap agent 4 bids 37 (credits left: 1000)
#   ❌ davide passes at 37
#   🚫 tommi cannot bid (no slot/credits)
#   💰 gianmarco bids 38 (credits left: 976)
#   💰 carlomario bids 39 (credits left: 1000)
#   💰 cap agent 1 bids 40 (credits left: 1000)
#   💰 cap agent 2 bids 41 (credits left: 1000)
#   💰 cap agent 3 bids 42 (credits left: 1000)
#   💰 cap agent 4 bids 43 (credits left: 1000)
#   💰 davide bids 44 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   ❌ gianmarco passes at 44
#   💰 carlomario bids 45 (credits left: 1000)
#   💰 cap agent 1 bids 46 (credits left: 1000)
#   💰 cap agent 2 bids 47 (credits left: 1000)
#   💰 cap agent 3 bids 48 (credits left: 1000)
#   💰 cap agent 4 bids 49 (credits left: 1000)
#   ❌ davide passes at 49
#   🚫 tommi cannot bid (no slot/credits)
#   💰 gianmarco bids 50 (credits left: 976)
#   💰 carlomario bids 51 (credits left: 1000)
#   💰 cap agent 1 bids 52 (credits left: 1000)
#   💰 cap agent 2 bids 53 (credits left: 1000)
#   💰 cap agent 3 bids 54 (credits left: 1000)
#   💰 cap agent 4 bids 55 (credits left: 1000)
#   ❌ davide passes at 55
#   🚫 tommi cannot bid (no slot/credits)
#   ❌ gianmarco passes at 55
#   ❌ carlomario passes at 55
#   💰 cap agent 1 bids 56 (credits left: 1000)
#   💰 cap agent 2 bids 57 (credits left: 1000)
#   💰 cap agent 3 bids 58 (credits left: 1000)
#   💰 cap agent 4 bids 59 (credits left: 1000)
#   ❌ davide passes at 59
#   🚫 tommi cannot bid (no slot/credits)
#   💰 gianmarco bids 60 (credits left: 976)
#   ❌ carlomario passes at 60
#   💰 cap agent 1 bids 61 (credits left: 1000)
#   💰 cap agent 2 bids 62 (credits left: 1000)
#   💰 cap agent 3 bids 63 (credits left: 1000)
#   ❌ cap agent 4 passes at 63
#   💰 davide bids 64 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   💰 gianmarco bids 65 (credits left: 976)
#   💰 carlomario bids 66 (credits left: 1000)
#   💰 cap agent 1 bids 67 (credits left: 1000)
#   💰 cap agent 2 bids 68 (credits left: 1000)
#   ❌ cap agent 3 passes at 68
#   ❌ cap agent 4 passes at 68
#   ❌ davide passes at 68
#   🚫 tommi cannot bid (no slot/credits)
#   ❌ gianmarco passes at 68
#   ❌ carlomario passes at 68
#   💰 cap agent 1 bids 69 (credits left: 1000)
#   💰 cap agent 2 bids 70 (credits left: 1000)
#   ❌ cap agent 3 passes at 70
#   ❌ cap agent 4 passes at 70
#   ❌ davide passes at 70
#   🚫 tommi cannot bid (no slot/credits)
#   💰 gianmarco bids 71 (credits left: 976)
#   💰 carlomario bids 72 (credits left: 1000)
#   💰 cap agent 1 bids 73 (credits left: 1000)
#   💰 cap agent 2 bids 74 (credits left: 1000)
#   ❌ cap agent 3 passes at 74
#   ❌ cap agent 4 passes at 74
#   💰 davide bids 75 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   ❌ gianmarco passes at 75
#   ❌ carlomario passes at 75
#   💰 cap agent 1 bids 76 (credits left: 1000)
#   ❌ cap agent 2 passes at 76
#   ❌ cap agent 3 passes at 76
#   ❌ cap agent 4 passes at 76
#   💰 davide bids 77 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   ❌ gianmarco passes at 77
#   💰 carlomario bids 78 (credits left: 1000)
#   💰 cap agent 1 bids 79 (credits left: 1000)
#   ❌ cap agent 2 passes at 79
#   ❌ cap agent 3 passes at 79
#   ❌ cap agent 4 passes at 79
#   💰 davide bids 80 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   💰 gianmarco bids 81 (credits left: 976)
#   ❌ carlomario passes at 81
#   💰 cap agent 1 bids 82 (credits left: 1000)
#   ❌ cap agent 2 passes at 82
#   ❌ cap agent 3 passes at 82
#   ❌ cap agent 4 passes at 82
#   💰 davide bids 83 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   ❌ gianmarco passes at 83
#   💰 carlomario bids 84 (credits left: 1000)
#   💰 cap agent 1 bids 85 (credits left: 1000)
#   ❌ cap agent 2 passes at 85
#   ❌ cap agent 3 passes at 85
#   ❌ cap agent 4 passes at 85
#   ❌ davide passes at 85
#   🚫 tommi cannot bid (no slot/credits)
#   💰 gianmarco bids 86 (credits left: 976)
#   💰 carlomario bids 87 (credits left: 1000)
#   💰 cap agent 1 bids 88 (credits left: 1000)
#   ❌ cap agent 2 passes at 88
#   ❌ cap agent 3 passes at 88
#   ❌ cap agent 4 passes at 88
#   ❌ davide passes at 88
#   🚫 tommi cannot bid (no slot/credits)
#   ❌ gianmarco passes at 88
#   ❌ carlomario passes at 88
# ✅ Di Gregorio SOLD to cap agent 1 for 88. Credits remaining: 912
#
# 🏆 AUCTION START: Torriani (GK) - Evaluation: 1
#   ❌ cap agent 1 passes at 0
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   ❌ cap agent 4 passes at 0
#   💰 davide bids 1 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   💰 gianmarco bids 2 (credits left: 976)
#   ❌ carlomario passes at 2
#   ❌ cap agent 1 passes at 2
#   ❌ cap agent 2 passes at 2
#   ❌ cap agent 3 passes at 2
#   ❌ cap agent 4 passes at 2
#   ❌ davide passes at 2
#   🚫 tommi cannot bid (no slot/credits)
# ✅ Torriani SOLD to gianmarco for 2. Credits remaining: 974
#
# 🏆 AUCTION START: Meret (GK) - Evaluation: 92
#   💰 cap agent 1 bids 1 (credits left: 912)
#   💰 cap agent 2 bids 2 (credits left: 1000)
#   💰 cap agent 3 bids 3 (credits left: 1000)
#   💰 cap agent 4 bids 4 (credits left: 1000)
#   ❌ davide passes at 4
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 4
#   💰 cap agent 1 bids 5 (credits left: 912)
#   💰 cap agent 2 bids 6 (credits left: 1000)
#   💰 cap agent 3 bids 7 (credits left: 1000)
#   💰 cap agent 4 bids 8 (credits left: 1000)
#   ❌ davide passes at 8
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 8
#   💰 cap agent 1 bids 9 (credits left: 912)
#   💰 cap agent 2 bids 10 (credits left: 1000)
#   💰 cap agent 3 bids 11 (credits left: 1000)
#   💰 cap agent 4 bids 12 (credits left: 1000)
#   💰 davide bids 13 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 14 (credits left: 1000)
#   💰 cap agent 1 bids 15 (credits left: 912)
#   💰 cap agent 2 bids 16 (credits left: 1000)
#   💰 cap agent 3 bids 17 (credits left: 1000)
#   💰 cap agent 4 bids 18 (credits left: 1000)
#   💰 davide bids 19 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 19
#   💰 cap agent 1 bids 20 (credits left: 912)
#   💰 cap agent 2 bids 21 (credits left: 1000)
#   💰 cap agent 3 bids 22 (credits left: 1000)
#   💰 cap agent 4 bids 23 (credits left: 1000)
#   ❌ davide passes at 23
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 24 (credits left: 1000)
#   💰 cap agent 1 bids 25 (credits left: 912)
#   💰 cap agent 2 bids 26 (credits left: 1000)
#   💰 cap agent 3 bids 27 (credits left: 1000)
#   💰 cap agent 4 bids 28 (credits left: 1000)
#   💰 davide bids 29 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 29
#   💰 cap agent 1 bids 30 (credits left: 912)
#   💰 cap agent 2 bids 31 (credits left: 1000)
#   💰 cap agent 3 bids 32 (credits left: 1000)
#   💰 cap agent 4 bids 33 (credits left: 1000)
#   💰 davide bids 34 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 35 (credits left: 1000)
#   💰 cap agent 1 bids 36 (credits left: 912)
#   💰 cap agent 2 bids 37 (credits left: 1000)
#   💰 cap agent 3 bids 38 (credits left: 1000)
#   💰 cap agent 4 bids 39 (credits left: 1000)
#   💰 davide bids 40 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 40
#   💰 cap agent 1 bids 41 (credits left: 912)
#   💰 cap agent 2 bids 42 (credits left: 1000)
#   💰 cap agent 3 bids 43 (credits left: 1000)
#   💰 cap agent 4 bids 44 (credits left: 1000)
#   💰 davide bids 45 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 46 (credits left: 1000)
#   💰 cap agent 1 bids 47 (credits left: 912)
#   💰 cap agent 2 bids 48 (credits left: 1000)
#   💰 cap agent 3 bids 49 (credits left: 1000)
#   💰 cap agent 4 bids 50 (credits left: 1000)
#   ❌ davide passes at 50
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 51 (credits left: 1000)
#   💰 cap agent 1 bids 52 (credits left: 912)
#   💰 cap agent 2 bids 53 (credits left: 1000)
#   💰 cap agent 3 bids 54 (credits left: 1000)
#   💰 cap agent 4 bids 55 (credits left: 1000)
#   ❌ davide passes at 55
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 55
#   💰 cap agent 1 bids 56 (credits left: 912)
#   💰 cap agent 2 bids 57 (credits left: 1000)
#   💰 cap agent 3 bids 58 (credits left: 1000)
#   💰 cap agent 4 bids 59 (credits left: 1000)
#   💰 davide bids 60 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 61 (credits left: 1000)
#   💰 cap agent 1 bids 62 (credits left: 912)
#   💰 cap agent 2 bids 63 (credits left: 1000)
#   💰 cap agent 3 bids 64 (credits left: 1000)
#   💰 cap agent 4 bids 65 (credits left: 1000)
#   ❌ davide passes at 65
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 65
#   💰 cap agent 1 bids 66 (credits left: 912)
#   💰 cap agent 2 bids 67 (credits left: 1000)
#   💰 cap agent 3 bids 68 (credits left: 1000)
#   ❌ cap agent 4 passes at 68
#   ❌ davide passes at 68
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 69 (credits left: 1000)
#   💰 cap agent 1 bids 70 (credits left: 912)
#   💰 cap agent 2 bids 71 (credits left: 1000)
#   💰 cap agent 3 bids 72 (credits left: 1000)
#   ❌ cap agent 4 passes at 72
#   ❌ davide passes at 72
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 72
#   💰 cap agent 1 bids 73 (credits left: 912)
#   💰 cap agent 2 bids 74 (credits left: 1000)
#   ❌ cap agent 3 passes at 74
#   ❌ cap agent 4 passes at 74
#   💰 davide bids 75 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 75
#   💰 cap agent 1 bids 76 (credits left: 912)
#   💰 cap agent 2 bids 77 (credits left: 1000)
#   ❌ cap agent 3 passes at 77
#   ❌ cap agent 4 passes at 77
#   💰 davide bids 78 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 78
#   💰 cap agent 1 bids 79 (credits left: 912)
#   💰 cap agent 2 bids 80 (credits left: 1000)
#   ❌ cap agent 3 passes at 80
#   ❌ cap agent 4 passes at 80
#   💰 davide bids 81 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 81
#   💰 cap agent 1 bids 82 (credits left: 912)
#   ❌ cap agent 2 passes at 82
#   ❌ cap agent 3 passes at 82
#   ❌ cap agent 4 passes at 82
#   💰 davide bids 83 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 84 (credits left: 1000)
#   💰 cap agent 1 bids 85 (credits left: 912)
#   ❌ cap agent 2 passes at 85
#   ❌ cap agent 3 passes at 85
#   ❌ cap agent 4 passes at 85
#   💰 davide bids 86 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 87 (credits left: 1000)
#   💰 cap agent 1 bids 88 (credits left: 912)
#   ❌ cap agent 2 passes at 88
#   ❌ cap agent 3 passes at 88
#   ❌ cap agent 4 passes at 88
#   💰 davide bids 89 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 89
#   💰 cap agent 1 bids 90 (credits left: 912)
#   ❌ cap agent 2 passes at 90
#   ❌ cap agent 3 passes at 90
#   ❌ cap agent 4 passes at 90
#   ❌ davide passes at 90
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 91 (credits left: 1000)
#   💰 cap agent 1 bids 92 (credits left: 912)
#   ❌ cap agent 2 passes at 92
#   ❌ cap agent 3 passes at 92
#   ❌ cap agent 4 passes at 92
#   💰 davide bids 93 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 93
#   💰 cap agent 1 bids 94 (credits left: 912)
#   ❌ cap agent 2 passes at 94
#   ❌ cap agent 3 passes at 94
#   ❌ cap agent 4 passes at 94
#   ❌ davide passes at 94
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 94
# ✅ Meret SOLD to cap agent 1 for 94. Credits remaining: 818
#
# 🏆 AUCTION START: Falcone (GK) - Evaluation: 14
#   ❌ cap agent 1 passes at 0
#   ❌ cap agent 2 passes at 0
#   💰 cap agent 3 bids 1 (credits left: 1000)
#   💰 cap agent 4 bids 2 (credits left: 1000)
#   💰 davide bids 3 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 4 (credits left: 1000)
#   ❌ cap agent 1 passes at 4
#   ❌ cap agent 2 passes at 4
#   ❌ cap agent 3 passes at 4
#   💰 cap agent 4 bids 5 (credits left: 1000)
#   ❌ davide passes at 5
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 6 (credits left: 1000)
#   ❌ cap agent 1 passes at 6
#   ❌ cap agent 2 passes at 6
#   ❌ cap agent 3 passes at 6
#   💰 cap agent 4 bids 7 (credits left: 1000)
#   💰 davide bids 8 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 9 (credits left: 1000)
#   ❌ cap agent 1 passes at 9
#   ❌ cap agent 2 passes at 9
#   ❌ cap agent 3 passes at 9
#   ❌ cap agent 4 passes at 9
#   💰 davide bids 10 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 11 (credits left: 1000)
#   ❌ cap agent 1 passes at 11
#   ❌ cap agent 2 passes at 11
#   ❌ cap agent 3 passes at 11
#   ❌ cap agent 4 passes at 11
#   💰 davide bids 12 (credits left: 1000)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 12
#   ❌ cap agent 1 passes at 12
#   ❌ cap agent 2 passes at 12
#   ❌ cap agent 3 passes at 12
#   ❌ cap agent 4 passes at 12
# ✅ Falcone SOLD to davide for 12. Credits remaining: 988
#
# 🏆 AUCTION START: Furlanetto (GK) - Evaluation: 1
#   ❌ cap agent 1 passes at 0
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   ❌ cap agent 4 passes at 0
#   ❌ davide passes at 0
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
# ❌ Furlanetto UNSOLD
#
# 🏆 AUCTION START: Svilar (GK) - Evaluation: 82
#   💰 cap agent 1 bids 1 (credits left: 818)
#   💰 cap agent 2 bids 2 (credits left: 1000)
#   💰 cap agent 3 bids 3 (credits left: 1000)
#   💰 cap agent 4 bids 4 (credits left: 1000)
#   💰 davide bids 5 (credits left: 988)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 6 (credits left: 1000)
#   💰 cap agent 1 bids 7 (credits left: 818)
#   💰 cap agent 2 bids 8 (credits left: 1000)
#   💰 cap agent 3 bids 9 (credits left: 1000)
#   💰 cap agent 4 bids 10 (credits left: 1000)
#   ❌ davide passes at 10
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 11 (credits left: 1000)
#   💰 cap agent 1 bids 12 (credits left: 818)
#   💰 cap agent 2 bids 13 (credits left: 1000)
#   💰 cap agent 3 bids 14 (credits left: 1000)
#   💰 cap agent 4 bids 15 (credits left: 1000)
#   ❌ davide passes at 15
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 15
#   💰 cap agent 1 bids 16 (credits left: 818)
#   💰 cap agent 2 bids 17 (credits left: 1000)
#   💰 cap agent 3 bids 18 (credits left: 1000)
#   💰 cap agent 4 bids 19 (credits left: 1000)
#   ❌ davide passes at 19
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 19
#   💰 cap agent 1 bids 20 (credits left: 818)
#   💰 cap agent 2 bids 21 (credits left: 1000)
#   💰 cap agent 3 bids 22 (credits left: 1000)
#   💰 cap agent 4 bids 23 (credits left: 1000)
#   💰 davide bids 24 (credits left: 988)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 25 (credits left: 1000)
#   💰 cap agent 1 bids 26 (credits left: 818)
#   💰 cap agent 2 bids 27 (credits left: 1000)
#   💰 cap agent 3 bids 28 (credits left: 1000)
#   💰 cap agent 4 bids 29 (credits left: 1000)
#   💰 davide bids 30 (credits left: 988)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 31 (credits left: 1000)
#   💰 cap agent 1 bids 32 (credits left: 818)
#   💰 cap agent 2 bids 33 (credits left: 1000)
#   💰 cap agent 3 bids 34 (credits left: 1000)
#   💰 cap agent 4 bids 35 (credits left: 1000)
#   ❌ davide passes at 35
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 36 (credits left: 1000)
#   💰 cap agent 1 bids 37 (credits left: 818)
#   💰 cap agent 2 bids 38 (credits left: 1000)
#   💰 cap agent 3 bids 39 (credits left: 1000)
#   💰 cap agent 4 bids 40 (credits left: 1000)
#   💰 davide bids 41 (credits left: 988)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 41
#   💰 cap agent 1 bids 42 (credits left: 818)
#   💰 cap agent 2 bids 43 (credits left: 1000)
#   💰 cap agent 3 bids 44 (credits left: 1000)
#   💰 cap agent 4 bids 45 (credits left: 1000)
#   ❌ davide passes at 45
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 45
#   💰 cap agent 1 bids 46 (credits left: 818)
#   💰 cap agent 2 bids 47 (credits left: 1000)
#   💰 cap agent 3 bids 48 (credits left: 1000)
#   💰 cap agent 4 bids 49 (credits left: 1000)
#   💰 davide bids 50 (credits left: 988)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 50
#   💰 cap agent 1 bids 51 (credits left: 818)
#   💰 cap agent 2 bids 52 (credits left: 1000)
#   💰 cap agent 3 bids 53 (credits left: 1000)
#   💰 cap agent 4 bids 54 (credits left: 1000)
#   ❌ davide passes at 54
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 54
#   💰 cap agent 1 bids 55 (credits left: 818)
#   💰 cap agent 2 bids 56 (credits left: 1000)
#   💰 cap agent 3 bids 57 (credits left: 1000)
#   💰 cap agent 4 bids 58 (credits left: 1000)
#   💰 davide bids 59 (credits left: 988)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 59
#   💰 cap agent 1 bids 60 (credits left: 818)
#   💰 cap agent 2 bids 61 (credits left: 1000)
#   💰 cap agent 3 bids 62 (credits left: 1000)
#   ❌ cap agent 4 passes at 62
#   💰 davide bids 63 (credits left: 988)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 63
#   💰 cap agent 1 bids 64 (credits left: 818)
#   💰 cap agent 2 bids 65 (credits left: 1000)
#   💰 cap agent 3 bids 66 (credits left: 1000)
#   ❌ cap agent 4 passes at 66
#   💰 davide bids 67 (credits left: 988)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 68 (credits left: 1000)
#   💰 cap agent 1 bids 69 (credits left: 818)
#   💰 cap agent 2 bids 70 (credits left: 1000)
#   ❌ cap agent 3 passes at 70
#   ❌ cap agent 4 passes at 70
#   ❌ davide passes at 70
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 71 (credits left: 1000)
#   💰 cap agent 1 bids 72 (credits left: 818)
#   💰 cap agent 2 bids 73 (credits left: 1000)
#   ❌ cap agent 3 passes at 73
#   ❌ cap agent 4 passes at 73
#   ❌ davide passes at 73
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 73
#   💰 cap agent 1 bids 74 (credits left: 818)
#   ❌ cap agent 2 passes at 74
#   ❌ cap agent 3 passes at 74
#   ❌ cap agent 4 passes at 74
#   💰 davide bids 75 (credits left: 988)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 76 (credits left: 1000)
#   💰 cap agent 1 bids 77 (credits left: 818)
#   ❌ cap agent 2 passes at 77
#   ❌ cap agent 3 passes at 77
#   ❌ cap agent 4 passes at 77
#   ❌ davide passes at 77
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 78 (credits left: 1000)
#   💰 cap agent 1 bids 79 (credits left: 818)
#   ❌ cap agent 2 passes at 79
#   ❌ cap agent 3 passes at 79
#   ❌ cap agent 4 passes at 79
#   💰 davide bids 80 (credits left: 988)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 81 (credits left: 1000)
#   💰 cap agent 1 bids 82 (credits left: 818)
#   ❌ cap agent 2 passes at 82
#   ❌ cap agent 3 passes at 82
#   ❌ cap agent 4 passes at 82
#   ❌ davide passes at 82
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 83 (credits left: 1000)
#   💰 cap agent 1 bids 84 (credits left: 818)
#   ❌ cap agent 2 passes at 84
#   ❌ cap agent 3 passes at 84
#   ❌ cap agent 4 passes at 84
#   ❌ davide passes at 84
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 85 (credits left: 1000)
#   💰 cap agent 1 bids 86 (credits left: 818)
#   ❌ cap agent 2 passes at 86
#   ❌ cap agent 3 passes at 86
#   ❌ cap agent 4 passes at 86
#   ❌ davide passes at 86
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 87 (credits left: 1000)
#   💰 cap agent 1 bids 88 (credits left: 818)
#   ❌ cap agent 2 passes at 88
#   ❌ cap agent 3 passes at 88
#   ❌ cap agent 4 passes at 88
#   ❌ davide passes at 88
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 88
# ✅ Svilar SOLD to cap agent 1 for 88. Credits remaining: 730
#
# 🏆 AUCTION START: Vigorito (GK) - Evaluation: 1
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   ❌ cap agent 4 passes at 0
#   💰 davide bids 1 (credits left: 988)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 1
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 1
#   ❌ cap agent 3 passes at 1
#   ❌ cap agent 4 passes at 1
# ✅ Vigorito SOLD to davide for 1. Credits remaining: 987
#
# 🏆 AUCTION START: Sava (GK) - Evaluation: 8
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 0
#   💰 cap agent 3 bids 1 (credits left: 1000)
#   💰 cap agent 4 bids 2 (credits left: 1000)
#   💰 davide bids 3 (credits left: 987)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 3
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 3
#   ❌ cap agent 3 passes at 3
#   💰 cap agent 4 bids 4 (credits left: 1000)
#   ❌ davide passes at 4
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 5 (credits left: 1000)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 5
#   ❌ cap agent 3 passes at 5
#   ❌ cap agent 4 passes at 5
#   ❌ davide passes at 5
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
# ✅ Sava SOLD to carlomario for 5. Credits remaining: 995
#
# 🏆 AUCTION START: Mandas (GK) - Evaluation: 12
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 0
#   💰 cap agent 3 bids 1 (credits left: 1000)
#   💰 cap agent 4 bids 2 (credits left: 1000)
#   ❌ davide passes at 2
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 2
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 2
#   💰 cap agent 3 bids 3 (credits left: 1000)
#   💰 cap agent 4 bids 4 (credits left: 1000)
#   ❌ davide passes at 4
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 5 (credits left: 995)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 5
#   ❌ cap agent 3 passes at 5
#   💰 cap agent 4 bids 6 (credits left: 1000)
#   ❌ davide passes at 6
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 6
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 6
#   ❌ cap agent 3 passes at 6
# ✅ Mandas SOLD to cap agent 4 for 6. Credits remaining: 994
#
# 🏆 AUCTION START: Caprile (GK) - Evaluation: 18
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 0
#   💰 cap agent 3 bids 1 (credits left: 1000)
#   💰 cap agent 4 bids 2 (credits left: 994)
#   💰 davide bids 3 (credits left: 987)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 3
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 3
#   💰 cap agent 3 bids 4 (credits left: 1000)
#   💰 cap agent 4 bids 5 (credits left: 994)
#   💰 davide bids 6 (credits left: 987)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 7 (credits left: 995)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 7
#   ❌ cap agent 3 passes at 7
#   💰 cap agent 4 bids 8 (credits left: 994)
#   ❌ davide passes at 8
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 9 (credits left: 995)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 9
#   ❌ cap agent 3 passes at 9
#   ❌ cap agent 4 passes at 9
#   ❌ davide passes at 9
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
# ✅ Caprile SOLD to carlomario for 9. Credits remaining: 986
#
# 🏆 AUCTION START: Paleari (GK) - Evaluation: 1
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   💰 cap agent 4 bids 1 (credits left: 994)
#   ❌ davide passes at 1
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 1
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 1
#   ❌ cap agent 3 passes at 1
# ✅ Paleari SOLD to cap agent 4 for 1. Credits remaining: 993
#
# 🏆 AUCTION START: Skorupski (GK) - Evaluation: 49
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 0
#   💰 cap agent 3 bids 1 (credits left: 1000)
#   💰 cap agent 4 bids 2 (credits left: 993)
#   ❌ davide passes at 2
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 2
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 2
#   💰 cap agent 3 bids 3 (credits left: 1000)
#   💰 cap agent 4 bids 4 (credits left: 993)
#   💰 davide bids 5 (credits left: 987)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 6 (credits left: 986)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 6
#   💰 cap agent 3 bids 7 (credits left: 1000)
#   💰 cap agent 4 bids 8 (credits left: 993)
#   💰 davide bids 9 (credits left: 987)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 10 (credits left: 986)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 10
#   💰 cap agent 3 bids 11 (credits left: 1000)
#   💰 cap agent 4 bids 12 (credits left: 993)
#   ❌ davide passes at 12
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   ❌ carlomario passes at 12
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 12
#   ❌ cap agent 3 passes at 12
# ✅ Skorupski SOLD to cap agent 4 for 12. Credits remaining: 981
#
# 🏆 AUCTION START: Pessina Mas. (GK) - Evaluation: 1
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   💰 davide bids 1 (credits left: 987)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 2 (credits left: 986)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 2
#   ❌ cap agent 3 passes at 2
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   💰 davide bids 3 (credits left: 987)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   💰 carlomario bids 4 (credits left: 986)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 4
#   ❌ cap agent 3 passes at 4
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   ❌ davide passes at 4
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
# ✅ Pessina Mas. SOLD to carlomario for 4. Credits remaining: 982
#
# 🏆 AUCTION START: Terracciano (GK) - Evaluation: 1
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   💰 davide bids 1 (credits left: 987)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 1
#   ❌ cap agent 3 passes at 1
#   🚫 cap agent 4 cannot bid (no slot/credits)
# ✅ Terracciano SOLD to davide for 1. Credits remaining: 986
#
# 🏆 AUCTION START: Scuffet (GK) - Evaluation: 5
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   ❌ cap agent 2 passes at 0
#   ❌ cap agent 3 passes at 0
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
# ❌ Scuffet UNSOLD
#
# 🏆 AUCTION START: De Gea (GK) - Evaluation: 62
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 1 (credits left: 1000)
#   💰 cap agent 3 bids 2 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 3 (credits left: 1000)
#   💰 cap agent 3 bids 4 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 5 (credits left: 1000)
#   💰 cap agent 3 bids 6 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 7 (credits left: 1000)
#   💰 cap agent 3 bids 8 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 9 (credits left: 1000)
#   💰 cap agent 3 bids 10 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 11 (credits left: 1000)
#   💰 cap agent 3 bids 12 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 13 (credits left: 1000)
#   💰 cap agent 3 bids 14 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 15 (credits left: 1000)
#   💰 cap agent 3 bids 16 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 17 (credits left: 1000)
#   💰 cap agent 3 bids 18 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 19 (credits left: 1000)
#   💰 cap agent 3 bids 20 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 21 (credits left: 1000)
#   💰 cap agent 3 bids 22 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 23 (credits left: 1000)
#   💰 cap agent 3 bids 24 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 25 (credits left: 1000)
#   💰 cap agent 3 bids 26 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 27 (credits left: 1000)
#   💰 cap agent 3 bids 28 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 29 (credits left: 1000)
#   💰 cap agent 3 bids 30 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 31 (credits left: 1000)
#   💰 cap agent 3 bids 32 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 33 (credits left: 1000)
#   💰 cap agent 3 bids 34 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 35 (credits left: 1000)
#   💰 cap agent 3 bids 36 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 37 (credits left: 1000)
#   💰 cap agent 3 bids 38 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 39 (credits left: 1000)
#   💰 cap agent 3 bids 40 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 41 (credits left: 1000)
#   💰 cap agent 3 bids 42 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 43 (credits left: 1000)
#   💰 cap agent 3 bids 44 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 45 (credits left: 1000)
#   💰 cap agent 3 bids 46 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 47 (credits left: 1000)
#   💰 cap agent 3 bids 48 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 49 (credits left: 1000)
#   💰 cap agent 3 bids 50 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 51 (credits left: 1000)
#   ❌ cap agent 3 passes at 51
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
# ✅ De Gea SOLD to cap agent 2 for 51. Credits remaining: 949
#
# 🏆 AUCTION START: Carnesecchi (GK) - Evaluation: 71
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 1 (credits left: 949)
#   💰 cap agent 3 bids 2 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 3 (credits left: 949)
#   💰 cap agent 3 bids 4 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 5 (credits left: 949)
#   💰 cap agent 3 bids 6 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 7 (credits left: 949)
#   💰 cap agent 3 bids 8 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 9 (credits left: 949)
#   💰 cap agent 3 bids 10 (credits left: 1000)
#   🚫 cap agent 4 cannot bid (no slot/credits)
#   🚫 davide cannot bid (no slot/credits)
#   🚫 tommi cannot bid (no slot/credits)
#   🚫 gianmarco cannot bid (no slot/credits)
#   🚫 carlomario cannot bid (no slot/credits)
#   🚫 cap agent 1 cannot bid (no slot/credits)
#   💰 cap agent 2 bids 11 (credits left: 949)
#   💰 cap agent 3 bids 12 (credits left: 1000)
# ...
#   DEF | Solet                | Udinese         | Eval:  37 | Cost:   1
#   DEF | Mancini              | Roma            | Eval:  30 | Cost:   1
#   DEF | Wesley               | Roma            | Eval:  52 | Cost:   1
#   DEF | Idrissi R.           | Cagliari        | Eval:   7 | Cost:   1
#   DEF | Olivera              | Napoli          | Eval:  26 | Cost:   1
#   DEF | Di Lorenzo           | Napoli          | Eval:  57 | Cost:   1
#   MID | Orsolini             | Bologna         | Eval: 220 | Cost: 177
#   MID | Calhanoglu           | Inter           | Eval: 152 | Cost: 123
#   MID | Tramoni M.           | Pisa            | Eval:  42 | Cost:  34
#   MID | Zielinski            | Inter           | Eval:  12 | Cost:   1
#   MID | Koopmeiners          | Juventus        | Eval:  40 | Cost:   4
#   MID | Isaksen              | Lazio           | Eval:  45 | Cost:   4
#   MID | Neres                | Napoli          | Eval:  43 | Cost:   4
#   MID | Pulisic              | Milan           | Eval: 216 | Cost:   4
#   ATT | Lookman              | Atalanta        | Eval: 296 | Cost: 249
#   ATT | Krstovic             | Lecce           | Eval: 138 | Cost: 111
#   ATT | Berardi              | Sassuolo        | Eval: 145 | Cost: 119
#   ATT | Soulè                | Roma            | Eval: 125 | Cost:   4
#   ATT | Immobile             | Bologna         | Eval: 140 | Cost:   4
#   ATT | Castro S.            | Bologna         | Eval: 140 | Cost:   2
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 2217
#   Total Squad Standardized: 5.784
#   Best XI Evaluation: 1484
#   Best XI Standardized: 3.884
#   Credits Remaining: 1
#   Total Credits Spent: 999
#
#
# 🏆 TEAM: CAP AGENT 3
# --------------------------------------------------
#   GK  | Okoye                | Udinese         | Eval:  17 | Cost:   1
#   GK  | Leali                | Genoa           | Eval:  28 | Cost:   1
#   GK  | Audero               | Cremonese       | Eval:  12 | Cost:   1
#   DEF | Lazaro               | Torino          | Eval:  19 | Cost:   1
#   DEF | Biraghi              | Torino          | Eval:  23 | Cost:   1
#   DEF | Romagnoli            | Lazio           | Eval:  22 | Cost:   1
#   DEF | Marusic              | Lazio           | Eval:  23 | Cost:   1
#   DEF | De Vrij              | Inter           | Eval:  20 | Cost:   1
#   DEF | De Winter            | Genoa           | Eval:  17 | Cost:   1
#   DEF | Vitik                | Bologna         | Eval:  18 | Cost:   1
#   DEF | Gila                 | Lazio           | Eval:  20 | Cost:   1
#   MID | Man                  | Parma           | Eval:  32 | Cost:   1
#   MID | Vazquez              | Cremonese       | Eval:  27 | Cost:   1
#   MID | Sohm                 | Parma           | Eval:  33 | Cost:   1
#   MID | Fofana Y.            | Milan           | Eval:  37 | Cost:   1
#   MID | Vandeputte           | Cremonese       | Eval:  36 | Cost:   1
#   MID | Da Cunha             | Como            | Eval:  33 | Cost:   1
#   MID | Bernabè              | Parma           | Eval:  35 | Cost:   1
#   MID | Guendouzi            | Lazio           | Eval:  24 | Cost:   1
#   ATT | Vlahovic             | Juventus        | Eval:  99 | Cost:  72
#   ATT | Gimenez              | Milan           | Eval: 261 | Cost: 187
#   ATT | Scamacca             | Atalanta        | Eval: 102 | Cost:   9
#   ATT | Martinez L.          | Inter           | Eval: 380 | Cost:   9
#   ATT | Camarda              | Lecce           | Eval:  22 | Cost:   1
#   ATT | Gonzalez N.          | Juventus        | Eval:  36 | Cost:   1
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 1376
#   Total Squad Standardized: 3.565
#   Best XI Evaluation: 1000
#   Best XI Standardized: 2.607
#   Credits Remaining: 702
#   Total Credits Spent: 298
#
#
# 🏆 TEAM: CAP AGENT 4
# --------------------------------------------------
#   GK  | Mandas               | Lazio           | Eval:  12 | Cost:   6
#   GK  | Paleari              | Torino          | Eval:   1 | Cost:   1
#   GK  | Skorupski            | Bologna         | Eval:  49 | Cost:  12
#   DEF | Marì                 | Fiorentina      | Eval:  16 | Cost:   6
#   DEF | Delprato             | Parma           | Eval:  21 | Cost:   7
#   DEF | Jimenez A.           | Milan           | Eval:  18 | Cost:   5
#   DEF | Kelly L.             | Juventus        | Eval:  17 | Cost:   6
#   DEF | Acerbi               | Inter           | Eval:  26 | Cost:   8
#   DEF | Vasquez              | Genoa           | Eval:  20 | Cost:   6
#   DEF | Kamara H.            | Udinese         | Eval:  19 | Cost:   6
#   DEF | Beukema              | Napoli          | Eval:  25 | Cost:   8
#   MID | Anjorin              | Torino          | Eval:  23 | Cost:   7
#   MID | Samardzic            | Atalanta        | Eval:  35 | Cost:  12
#   MID | Freuler              | Bologna         | Eval:  27 | Cost:   8
#   MID | Mandragora           | Fiorentina      | Eval:  33 | Cost:   8
#   MID | Casadei              | Torino          | Eval:  30 | Cost:   8
#   MID | Malinovskyi          | Genoa           | Eval:  25 | Cost:   8
#   MID | Thorstvedt           | Sassuolo        | Eval:  24 | Cost:   6
#   MID | Carboni V.           | Genoa           | Eval:  29 | Cost:   8
#   ATT | Pinamonti            | Sassuolo        | Eval:  73 | Cost:  36
#   ATT | Thauvin              | Udinese         | Eval:  80 | Cost:  38
#   ATT | Lucca                | Napoli          | Eval:  60 | Cost:  23
#   ATT | Lang                 | Napoli          | Eval:  94 | Cost:  24
#   ATT | Cambiaghi            | Bologna         | Eval:  26 | Cost:   8
#   ATT | Dzeko                | Fiorentina      | Eval:  71 | Cost:  18
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 854
#   Total Squad Standardized: 2.187
#   Best XI Evaluation: 515
#   Best XI Standardized: 1.327
#   Credits Remaining: 717
#   Total Credits Spent: 283
#
#
# 🏆 TEAM: DAVIDE
# --------------------------------------------------
#   GK  | Falcone              | Lecce           | Eval:  14 | Cost:  12
#   GK  | Vigorito             | Como            | Eval:   1 | Cost:   1
#   GK  | Terracciano          | Milan           | Eval:   1 | Cost:   1
#   DEF | Bastoni              | Inter           | Eval:  78 | Cost:  84
#   DEF | Norton-Cuffy         | Genoa           | Eval:   7 | Cost:   5
#   DEF | Valeri               | Parma           | Eval:  27 | Cost:  32
#   DEF | Zemura               | Udinese         | Eval:   8 | Cost:   1
#   DEF | Veiga D.             | Lecce           | Eval:   2 | Cost:   1
#   DEF | Coppola F.           | Pisa            | Eval:   4 | Cost:   1
#   DEF | Cabal                | Juventus        | Eval:  10 | Cost:   1
#   DEF | Gigot                | Lazio           | Eval:   8 | Cost:   1
#   MID | Cataldi              | Lazio           | Eval:   7 | Cost:   4
#   MID | Frattesi             | Inter           | Eval:  54 | Cost:  59
#   MID | McKennie             | Juventus        | Eval:  24 | Cost:  18
#   MID | Rovella              | Lazio           | Eval:  22 | Cost:   1
#   MID | Niasse               | Verona          | Eval:   6 | Cost:   1
#   MID | Ramadani             | Lecce           | Eval:  11 | Cost:   4
#   MID | Stanciu              | Genoa           | Eval:  19 | Cost:   1
#   MID | Thorsby              | Genoa           | Eval:  12 | Cost:  10
#   ATT | Luvumbo              | Cagliari        | Eval:  22 | Cost:  13
#   ATT | Ngonge               | Torino          | Eval:  24 | Cost:  16
#   ATT | Pellegrino M.        | Parma           | Eval:  61 | Cost:  35
#   ATT | Skjellerup           | Sassuolo        | Eval:   1 | Cost:   1
#   ATT | Mulattieri           | Sassuolo        | Eval:  10 | Cost:   1
#   ATT | Diao                 | Como            | Eval:  95 | Cost:  85
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 528
#   Total Squad Standardized: 1.327
#   Best XI Evaluation: 436
#   Best XI Standardized: 1.119
#   Credits Remaining: 611
#   Total Credits Spent: 389
#
#
# 🏆 TEAM: TOMMI
# --------------------------------------------------
#   GK  | Sommariva            | Genoa           | Eval:   1 | Cost:   2
#   GK  | Di Gennaro           | Inter           | Eval:   1 | Cost:   2
#   GK  | Christensen O.       | Fiorentina      | Eval:   1 | Cost:   5
#   DEF | Ehizibue             | Udinese         | Eval:  15 | Cost:   2
#   DEF | Marianucci           | Napoli          | Eval:   9 | Cost:   2
#   DEF | Otoa                 | Genoa           | Eval:   3 | Cost:   3
#   DEF | Hien                 | Atalanta        | Eval:  40 | Cost:  43
#   DEF | Pieragnolo           | Sassuolo        | Eval:   4 | Cost:   4
#   DEF | Rensch               | Roma            | Eval:  14 | Cost:   2
#   DEF | Kossounou            | Atalanta        | Eval:  22 | Cost:  12
#   DEF | Luperto              | Cagliari        | Eval:  18 | Cost:   9
#   MID | Perrone              | Como            | Eval:  19 | Cost:  13
#   MID | Tourè I.             | Pisa            | Eval:  11 | Cost:   6
#   MID | Ricci S.             | Milan           | Eval:  27 | Cost:  13
#   MID | Zanimacchia          | Cremonese       | Eval:  10 | Cost:   4
#   MID | Basic                | Lazio           | Eval:   1 | Cost:  32
#   MID | El Aynaoui           | Roma            | Eval:  29 | Cost:  25
#   MID | Konè M.              | Roma            | Eval:  41 | Cost:  45
#   MID | Lobotka              | Napoli          | Eval:  23 | Cost:  23
#   ATT | Cancellieri          | Lazio           | Eval:   6 | Cost:   6
#   ATT | Gabrielloni          | Como            | Eval:   1 | Cost:   8
#   ATT | Pavoletti            | Cagliari        | Eval:   3 | Cost:   4
#   ATT | Esposito F.P.        | Inter           | Eval:  13 | Cost:   3
#   ATT | Yildiz               | Juventus        | Eval: 235 | Cost: 212
#   ATT | Okereke              | Cremonese       | Eval:   7 | Cost:  43
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 554
#   Total Squad Standardized: 1.396
#   Best XI Evaluation: 471
#   Best XI Standardized: 1.211
#   Credits Remaining: 477
#   Total Credits Spent: 523
#
#
# 🏆 TEAM: GIANMARCO
# --------------------------------------------------
#   GK  | Nunziante            | Udinese         | Eval:   1 | Cost:  14
#   GK  | Donnarumma An.       | Torino          | Eval:   1 | Cost:  10
#   GK  | Torriani             | Milan           | Eval:   1 | Cost:   2
#   DEF | Gaspar K.            | Lecce           | Eval:  19 | Cost:  27
#   DEF | Salah-Eddine         | Roma            | Eval:   9 | Cost:   2
#   DEF | Slotsager            | Verona          | Eval:   5 | Cost:   4
#   DEF | Bartesaghi           | Milan           | Eval:   5 | Cost:   7
#   DEF | Gosens               | Fiorentina      | Eval:  86 | Cost: 110
#   DEF | De Silvestri         | Bologna         | Eval:  12 | Cost:   3
#   DEF | Dodò                 | Fiorentina      | Eval:  44 | Cost:  55
#   DEF | Parisi               | Fiorentina      | Eval:  11 | Cost:   9
#   MID | Atta                 | Udinese         | Eval:  16 | Cost:   2
#   MID | Helgason             | Lecce           | Eval:  24 | Cost:  27
#   MID | Douglas Luiz         | Juventus        | Eval:   6 | Cost:  18
#   MID | Pickel               | Cremonese       | Eval:   5 | Cost:   1
#   MID | Piccinini G.         | Pisa            | Eval:   9 | Cost:  11
#   MID | Bianco               | Fiorentina      | Eval:   2 | Cost:   2
#   MID | Chukwueze            | Milan           | Eval:  11 | Cost:   1
#   MID | Gineitis             | Torino          | Eval:   9 | Cost:   3
#   ATT | Dallinga             | Bologna         | Eval:  18 | Cost:   5
#   ATT | Sarr A.              | Verona          | Eval:  24 | Cost:  29
#   ATT | Rodriguez Je.        | Como            | Eval:  14 | Cost:  25
#   ATT | Dominguez B.         | Bologna         | Eval:  24 | Cost:  14
#   ATT | Azon                 | Como            | Eval:   5 | Cost:   1
#   ATT | Lind                 | Pisa            | Eval:  11 | Cost:   3
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 372
#   Total Squad Standardized: 0.916
#   Best XI Evaluation: 288
#   Best XI Standardized: 0.728
#   Credits Remaining: 615
#   Total Credits Spent: 385
#
#
# 🏆 TEAM: CARLOMARIO
# --------------------------------------------------
#   GK  | Sava                 | Udinese         | Eval:   8 | Cost:   5
#   GK  | Caprile              | Cagliari        | Eval:  18 | Cost:   9
#   GK  | Pessina Mas.         | Bologna         | Eval:   1 | Cost:   4
#   DEF | N'Dicka              | Roma            | Eval:  26 | Cost:  17
#   DEF | Kalulu               | Juventus        | Eval:  24 | Cost:  22
#   DEF | Comuzzo              | Fiorentina      | Eval:  17 | Cost:  10
#   DEF | Perez M.             | Lecce           | Eval:   1 | Cost:   9
#   DEF | Posch                | Bologna         | Eval:  12 | Cost:   8
#   DEF | Bertola              | Udinese         | Eval:  11 | Cost:  12
#   DEF | Ravanelli            | Cremonese       | Eval:   3 | Cost:   3
#   DEF | Pavlovic             | Milan           | Eval:  21 | Cost:  13
#   MID | Fadera               | Sassuolo        | Eval:  16 | Cost:   3
#   MID | Folorunsho           | Cagliari        | Eval:  27 | Cost:  30
#   MID | Zambo Anguissa       | Napoli          | Eval:  54 | Cost:  71
#   MID | Iannoni              | Sassuolo        | Eval:   2 | Cost:  12
#   MID | Ederson D.S.         | Atalanta        | Eval:  58 | Cost:  67
#   MID | Payero               | Udinese         | Eval:  10 | Cost:  22
#   MID | Ellertsson           | Genoa           | Eval:  15 | Cost:  20
#   MID | Karlstrom            | Udinese         | Eval:  14 | Cost:   4
#   ATT | Dia                  | Lazio           | Eval: 147 | Cost: 145
#   ATT | Davis K.             | Udinese         | Eval:  28 | Cost:  24
#   ATT | Meister              | Pisa            | Eval:   1 | Cost:   6
#   ATT | Simeone              | Napoli          | Eval:   5 | Cost:  12
#   ATT | Lukaku               | Napoli          | Eval: 341 | Cost: 302
#   ATT | Banda                | Lecce           | Eval:   8 | Cost:   3
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 868
#   Total Squad Standardized: 2.224
#   Best XI Evaluation: 777
#   Best XI Standardized: 2.018
#   Credits Remaining: 167
#   Total Credits Spent: 833
#
#
# 🏆 TEAM: CAP AGENT 1
# --------------------------------------------------
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 2592
#   Total Squad Standardized: 6.773
#   Best XI Evaluation: 1759
#   Best XI Standardized: 4.609
#   Credits Remaining: 0
#   Total Credits Spent: 1000
#
#
# 🏆 TEAM: CAP AGENT 2
# --------------------------------------------------
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 2217
#   Total Squad Standardized: 5.784
#   Best XI Evaluation: 1484
#   Best XI Standardized: 3.884
#   Credits Remaining: 1
#   Total Credits Spent: 999
#
#
# 🏆 TEAM: CAP AGENT 3
# --------------------------------------------------
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 1376
#   Total Squad Standardized: 3.565
#   Best XI Evaluation: 1000
#   Best XI Standardized: 2.607
#   Credits Remaining: 702
#   Total Credits Spent: 298
#
#
# 🏆 TEAM: CAP AGENT 4
# --------------------------------------------------
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 854
#   Total Squad Standardized: 2.187
#   Best XI Evaluation: 515
#   Best XI Standardized: 1.327
#   Credits Remaining: 717
#   Total Credits Spent: 283
#
#
# 🏆 TEAM: DAVIDE
# --------------------------------------------------
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 528
#   Total Squad Standardized: 1.327
#   Best XI Evaluation: 436
#   Best XI Standardized: 1.119
#   Credits Remaining: 611
#   Total Credits Spent: 389
#
#
# 🏆 TEAM: TOMMI
# --------------------------------------------------
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 554
#   Total Squad Standardized: 1.396
#   Best XI Evaluation: 471
#   Best XI Standardized: 1.211
#   Credits Remaining: 477
#   Total Credits Spent: 523
#
#
# 🏆 TEAM: GIANMARCO
# --------------------------------------------------
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 372
#   Total Squad Standardized: 0.916
#   Best XI Evaluation: 288
#   Best XI Standardized: 0.728
#   Credits Remaining: 615
#   Total Credits Spent: 385
#
#
# 🏆 TEAM: CARLOMARIO
# --------------------------------------------------
#
# 📈 SQUAD METRICS:
#   Total Squad Evaluation: 868
#   Total Squad Standardized: 2.224
#   Best XI Evaluation: 777
#   Best XI Standardized: 2.018
#   Credits Remaining: 167
#   Total Credits Spent: 833
#
#
# 📁 Complete log saved to: auction_log_20250802_225908.txt
